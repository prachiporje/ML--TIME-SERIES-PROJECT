# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
airpas=pd.read_csv("AirPassengers.csv")

# %%
airpas.shape
# Out:
# (144, 2)

# %%
airpas.head()
# Out:
#      Month  Passengers
# 0  1949-01         112
# 1  1949-02         118
# 2  1949-03         132
# 3  1949-04         129
# 4  1949-05         121

# %%
# month col is a date and time col 
airpas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Month       144 non-null    object
#  1   Passengers  144 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.4+ KB

# %%
# convert into datetime col 
airpas.Month= pd.to_datetime(airpas.Month,infer_datetime_format= True)

# %%
airpas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Month       144 non-null    datetime64[ns]
#  1   Passengers  144 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 2.4 KB

# %%
airpas.shape
# Out:
# (144, 2)

# %%
# lets convert month as in index

# %%
airpas = airpas.set_index(['Month'])

# %%
airpas.shape
# Out:
# (144, 1)

# %%
airpas.head(2)
# Out:
#             Passengers
# Month
# 1949-01-01         112
# 1949-02-01         118

# %%
# finally we need to build a model using auto arima and serima
#

# %%
# explore the data

# %%
plt.plot(airpas)
# trend ? - yes
# is this seasonal ? -yes
# ststionary ? 

# it

# %%
airpas.iloc[0:24]
# Out:
#             Passengers
# Month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121
# 1949-06-01         135
# 1949-07-01         148
# 1949-08-01         148
# 1949-09-01         136
# 1949-10-01         119
# 1949-11-01         104
# 1949-12-01         118
# 1950-01-01         115
# 1950-02-01         126
# 1950-03-01         141
# 1950-04-01         135
# 1950-05-01         125
# 1950-06-01         149
# 1950-07-01         170
# 1950-08-01         170
# 1950-09-01         158
# 1950-10-01         133
# 1950-11-01         114
# 1950-12-01         140

# %%
# make it stationary 
# we take differencing

# %%
airpas.Passengers
# Out:
# Month
# 1949-01-01    112
# 1949-02-01    118
# 1949-03-01    132
# 1949-04-01    129
# 1949-05-01    121
#              ...
# 1960-08-01    606
# 1960-09-01    508
# 1960-10-01    461
# 1960-11-01    390
# 1960-12-01    432
# Name: Passengers, Length: 144, dtype: int64

# %%
6,14,-3,-8 # diff values
# Out:
# (6, 14, -3, -8)

# %%
airpas.Passengers.diff()
# Out:
# Month
# 1949-01-01     NaN
# 1949-02-01     6.0
# 1949-03-01    14.0
# 1949-04-01    -3.0
# 1949-05-01    -8.0
#               ...
# 1960-08-01   -16.0
# 1960-09-01   -98.0
# 1960-10-01   -47.0
# 1960-11-01   -71.0
# 1960-12-01    42.0
# Name: Passengers, Length: 144, dtype: float64

# %%
plt.figure(figsize= (12,6))
plt.plot(airpas.Passengers.diff())

# %%
# its not stationary
# Out:
#   File "C:\Users\prachi porje\AppData\Local\Temp\ipykernel_9340\4063882566.py", line 2
#     1 -
#         ^
# SyntaxError: invalid syntax

# %%
airpas.Passengers.diff().diff() # 2 nd level

# %%
plt.figure(figsize= (12,6))
plt.plot(airpas.Passengers.diff().diff())

# %%
airpas.Passengers.diff().diff().diff()

# %%
plt.figure(figsize= (12,6))
plt.plot(airpas.Passengers.diff().diff().diff())

# %%
airpas.Passengers.diff().diff().diff().diff()

# %%
plt.figure(figsize= (12,6))
plt.plot(airpas.Passengers.diff().diff().diff().diff())

# %%
airpas.Passengers.diff().diff().diff().diff().diff()

# %%
plt.figure(figsize= (12,6))
plt.plot(airpas.Passengers.diff().diff().diff().diff().diff())

# %%
airpas.Passengers.diff().diff().diff().diff().diff().diff()

# %%
plt.figure(figsize= (12,6))
plt.plot(airpas.Passengers.diff().diff().diff().diff().diff().diff())

# %%
airpas.Passengers.diff().diff().diff().diff().diff().diff().diff()

# %%
plt.figure(figsize= (12,6))
plt.plot(airpas.Passengers.diff().diff().diff().diff().diff().diff().diff())

# %%
airpas.Passengers.diff().diff().diff().diff().diff().diff().diff().diff()

# %%
# final differencing ----->

plt.figure(figsize= (12,6))
plt.plot(airpas.Passengers.diff().diff().diff().diff().diff().diff().diff().diff())

# %%
# take log 
log_df = np.log(airpas)

# %%
plt.plot(log_df)

# %%
plt.plot(log_df.diff())

# %%
# data has been transformed into log  so when we do the forcast our forcasted value will also be in log 
# so to get the ans in original scale we need to tale anti log 

# big values get converted into samller values . it provides u the smothening effect 
# nit for 0 and - num

# %%
# examples---
# np.exp(9)

# %%
# np.exp(10)

# %%
# np.log(8103.083927575384)

# %%
# np.log(22026.465794806718)

# %%
# to build the model we need to know the values of p,q,d

# %%
# for exanple
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plot_acf(log_df)

# %%
plot_pacf(log_df) , # AR 2 process (p)
                    # Q 0 
                   # d -> 1
# Out:
# C:\Users\prachi porje\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(
# (<Figure size 640x480 with 1 Axes>,)

# %%
# 

from statsmodels.tsa.arima_model import ARIMA

# %%
model = ARIMA(log_df, order = (2,1,0)) # already been removed
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9340\3125835351.py in <module>
# ----> 1 model = ARIMA(log_df, order = (2,1,0)) # already been removed
#
# ~\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py in __init__(self, *args, **kwargs)
#      43
#      44     def __init__(self, *args, **kwargs):
# ---> 45         super().__init__(*args, **kwargs)
#      46
#      47
#
# ~\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py in __init__(self, *args, **kwargs)
#      27
#      28     def __init__(self, *args, **kwargs):
# ---> 29         raise NotImplementedError(ARIMA_DEPRECATION_ERROR)
#      30
#      31
#
# NotImplementedError:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been removed in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# ...

# %%
# lets build the model using sarimax

# for using sarimax we need to use auto arima to get the values 
# vaues of p,d,q-----  what ever values i get 
# pass themn in sarima

# %%
import pmdarima # if you get error then ----!pip install

# %%
from pmdarima import auto_arima

# %%
auto_arima(log_df)
# Out:
# ARIMA(order=(4, 1, 3), scoring_args={}, suppress_warnings=True)

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
model_sarima = SARIMAX(log_df, order = (4,1,3))
# Out:
# C:\Users\prachi porje\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\prachi porje\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
results= model_sarima.fit()
# Out:
# C:\Users\prachi porje\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
results.predict(start = 144 ,end= 155)
# Out:
# 1961-01-01    6.156098
# 1961-02-01    6.147531
# 1961-03-01    6.209251
# 1961-04-01    6.224668
# 1961-05-01    6.151303
# 1961-06-01    6.173249
# 1961-07-01    6.181041
# 1961-08-01    6.119857
# 1961-09-01    6.157942
# 1961-10-01    6.181809
# 1961-11-01    6.129964
# 1961-12-01    6.167535
# Freq: MS, Name: predicted_mean, dtype: float64

# %%
# take anti log but why? 
# np.log10(100)

# %%
# np.square(10)

# %%
pred = results.predict(start = 144 ,end= 155)

# %%
pred_actual_scale= np.exp(pred)

# %%
plt.plot(airpas, color ='red', label= '1949-60')
plt.plot(pred_actual_scale, color = 'green', label= 'Forcast')
plt.legend()

# %% [markdown]
# ## from the above graph we are convinced that model is not doing good forcast

# %%
SARIMAX -----> S atands for seasonality
# Out:
#   File "C:\Users\prachi porje\AppData\Local\Temp\ipykernel_9340\3228343989.py", line 1
#     SARIMAX -----> S atands for seasonality
#                 ^
# SyntaxError: invalid syntax

# %%
# wehn your data / deries has seoanality ARIMA doent not give good results
#  ARIMA cannot handel sesonality

# %%
# lets build the model which takes care of seasonality effect

# %%
model_sarima1= SARIMAX(log_df, order= (2,0, 0) , seasonal_order= (0,1,1, 12))
# Out:
# C:\Users\prachi porje\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\prachi porje\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
result1 = model_sarima1.fit()

# %%
pred1= result1.predict(start= 144, end= 175)

# %%
pred_actual_scale1= np.exp(pred1)

# %%
plt.plot(airpas, color ='red', label= '1949-60')
plt.plot(pred_actual_scale1, color = 'green', label= 'Forcast')
plt.legend()

# %%
from statsmodels.tsa.stattools import adfuller

# %%
adfuller(airpas.Passengers)
# how is that series is not stationaery 
# ha series is stationaery 

# since p value is more than .05 wefail to reject the null (null jis still true)
# inal conclusion (series is nit stationaery)
# Out:
# (0.8153688792060411,
#  0.9918802434376409,
#  13,
#  130,
#  {'1%': -3.4816817173418295,
#   '5%': -2.8840418343195267,
#   '10%': -2.578770059171598},
#  996.692930839019)

# %%
adfuller(airpas.passenger.diff().dropna())

# %%
# another test is KPSS

# %%
from statsmodels.tsa.stattools import kpss
# ho in kpss is series is stationery 
# ha is sseries is not stationery

# %%
kpss(airpas.Passengers)
# Out:
# C:\Users\prachi porje\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:2018: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   warnings.warn(
# (1.6513122354165206,
#  0.01,
#  8,
#  {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739})

# %%
def adf_test(series):
    from stats,odels.tsa.stattools import adfuller
